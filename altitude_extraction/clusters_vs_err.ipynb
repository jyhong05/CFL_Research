# %%
from cfl.experiment import Experiment
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from cfl_helpers import *
# Out:
# WARNING:tensorflow:From c:\Users\Justin Hong\OneDrive\Documents\CFL_Research\myvenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
resolution = '10km'
train_file = f'data/{resolution}_data.csv'
truth_file = f'data/{resolution}_truth.csv'

train_data = pd.read_csv(train_file)
Xraw = np.array(train_data[['lat', 'long']])
Yraw = np.array(train_data['generated_temp']).reshape(-1,1)
X = StandardScaler().fit_transform(Xraw)
Y = StandardScaler().fit_transform(Yraw)
print(Xraw.shape, Yraw.shape)

truth = pd.read_csv(truth_file)
true_alt, true_temp = get_alt_temp_grids(truth)
# Out:
# (12700, 2) (12700, 1)

# %%
data_info = {'X_dims' : X.shape,
             'Y_dims' : Y.shape,
             'Y_type' : 'continuous' #options: 'categorical' or 'continuous'
            }

CDE_params = {  'model'        : 'CondExpMod',
                'model_params' : {
                    # model architecture
                    'dense_units' : [50, data_info['Y_dims'][1]],
                    'activations' : ['relu', 'linear'],
                    'dropouts'    : [0, 0],
                    # training parameters
                    'batch_size'  : 64,
                    'n_epochs'    : 2000,
                    'optimizer'   : 'adam',
                    'opt_config'  : {'lr' : 1e-4},
                    'loss'        : 'mean_squared_error',
                    'best'        : True,
                    'early_stopping' : True,
                    # verbosity
                    'verbose'     : 0, # don't log or show plot for checking clusters vs accuracy
                    'show_plot'   : False,
                }
}

# CAUSE CLUSTER PARAMS VARIED

# %% [markdown]
# # number of cause clusters vs accuracy

# %%
n_clusters = [1, 5, 10, 15, 25, 50, 100, 150, 200, 300]
abs_accuracies = []

for n in n_clusters:
    cause_cluster_params =  {'model' : 'KMeans',
                         'model_params' : {'n_clusters' : n},
                         'verbose' : 0
    }

    block_names = ['CondDensityEstimator', 'CauseClusterer']
    block_params = [CDE_params, cause_cluster_params]
    results_path = 'sample_run' # directory to save results to

    my_exp = Experiment(X_train=X,
                        Y_train=Y,
                        data_info=data_info,
                        block_names=block_names,
                        block_params=block_params,
                        results_path=results_path)
    results = my_exp.train()

    xlbls = results['CauseClusterer']['x_lbls']
    pred_temps = reconstruct_groups(train_data, xlbls, plot=False)

    abs_accuracies.append(by_cluster_abs_err(train_data, xlbls, truth))
    print(f'abs_accuracy for {n} clusters: {abs_accuracies[-1]}')
# Out:
# All results from this run will be saved to sample_run\experiment0020
# Block: verbose not specified in input, defaulting to 1
# WARNING:tensorflow:From c:\Users\Justin Hong\OneDrive\Documents\CFL_Research\myvenv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# WARNING:tensorflow:From c:\Users\Justin Hong\OneDrive\Documents\CFL_Research\myvenv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\Users\Justin Hong\OneDrive\Documents\CFL_Research\myvenv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 397/397 [==============================] - 0s 541us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 1 clusters: 1.3314772680801696
# All results from this run will be saved to sample_run\experiment0021
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 509us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 5 clusters: 0.7168973159216238
# All results from this run will be saved to sample_run\experiment0022
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 522us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 10 clusters: 0.7014716607164267
# All results from this run will be saved to sample_run\experiment0023
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 529us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 15 clusters: 0.6573088731046673
# All results from this run will be saved to sample_run\experiment0024
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 547us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 25 clusters: 0.6437692208304574
# All results from this run will be saved to sample_run\experiment0025
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 554us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 50 clusters: 0.6964329043296535
# All results from this run will be saved to sample_run\experiment0026
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 531us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 100 clusters: 0.631772472826711
# All results from this run will be saved to sample_run\experiment0027
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 539us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 150 clusters: 0.5980279554429809
# All results from this run will be saved to sample_run\experiment0028
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 532us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 200 clusters: 0.6306347710637197
# All results from this run will be saved to sample_run\experiment0029
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 523us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 300 clusters: 0.6368053173863107

# %%
import matplotlib.pyplot as plt

plt.figure(0)
plt.plot(n_clusters, abs_accuracies)
plt.xlabel('Number of clusters')
plt.ylabel('Mean absolute error by cluster')
plt.title(f'Mean absolute error by cluster vs number of clusters - {resolution}')
# Out:
# Text(0.5, 1.0, 'Mean absolute error by cluster vs number of clusters - 10km')
