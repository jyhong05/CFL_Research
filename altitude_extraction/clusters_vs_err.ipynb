# %%
from cfl.experiment import Experiment
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from cfl_helpers import *

# %%
resolution = '10km'
train_file = f'data/{resolution}_data.csv'
truth_file = f'data/{resolution}_truth.csv'

train_data = pd.read_csv(train_file)
Xraw = np.array(train_data[['lat', 'long']])
Yraw = np.array(train_data['generated_temp']).reshape(-1,1)
X = StandardScaler().fit_transform(Xraw)
Y = StandardScaler().fit_transform(Yraw)
print(Xraw.shape, Yraw.shape)

truth = pd.read_csv(truth_file)
true_alt, true_temp = get_alt_temp_grids(truth)
# Out:
# (12700, 2) (12700, 1)

# %%
data_info = {'X_dims' : X.shape,
             'Y_dims' : Y.shape,
             'Y_type' : 'continuous' #options: 'categorical' or 'continuous'
            }

CDE_params = {  'model'        : 'CondExpMod',
                'model_params' : {
                    # model architecture
                    'dense_units' : [50, data_info['Y_dims'][1]],
                    'activations' : ['relu', 'linear'],
                    'dropouts'    : [0, 0],
                    # training parameters
                    'batch_size'  : 64,
                    'n_epochs'    : 2000,
                    'optimizer'   : 'adam',
                    'opt_config'  : {'lr' : 1e-4},
                    'loss'        : 'mean_squared_error',
                    'best'        : True,
                    'early_stopping' : True,
                    # verbosity
                    'verbose'     : 0, # don't log or show plot for checking clusters vs accuracy
                    'show_plot'   : False,
                }
}

# CAUSE CLUSTER PARAMS VARIED

# %% [markdown]
# # number of cause clusters vs accuracy

# %%
n_clusters = [1, 5, 10, 30, 50, 75, 100, 150, 200] # for 10km dataset
# n_clusters = [1, 3, 5, 10, 20, 30, 50, 100, 150] # for 25km and 40km datasets
abs_accuracies = []

for n in n_clusters:
    cause_cluster_params =  {'model' : 'KMeans',
                         'model_params' : {'n_clusters' : n},
                         'verbose' : 0
    }

    block_names = ['CondDensityEstimator', 'CauseClusterer']
    block_params = [CDE_params, cause_cluster_params]
    results_path = 'sample_run' # directory to save results to

    my_exp = Experiment(X_train=X,
                        Y_train=Y,
                        data_info=data_info,
                        block_names=block_names,
                        block_params=block_params,
                        results_path=results_path)
    results = my_exp.train()

    xlbls = results['CauseClusterer']['x_lbls']
    pred_temps = reconstruct_groups(train_data, xlbls, plot=False)

    abs_accuracies.append(by_cluster_abs_err(train_data, xlbls, truth))
    print(f'abs_accuracy for {n} clusters: {abs_accuracies[-1]}')
# Out:
# All results from this run will be saved to sample_run/experiment0054
# Block: verbose not specified in input, defaulting to 1
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 693us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 1 clusters: 1.3314772680801696
# All results from this run will be saved to sample_run/experiment0055
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 699us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 5 clusters: 0.7073440675030873
# All results from this run will be saved to sample_run/experiment0056
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 658us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 10 clusters: 0.6560425790676094
# All results from this run will be saved to sample_run/experiment0057
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 725us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 30 clusters: 0.7148286980941297
# All results from this run will be saved to sample_run/experiment0058
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 697us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 50 clusters: 0.6399618279736837
# All results from this run will be saved to sample_run/experiment0059
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 693us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 75 clusters: 0.6264762270329197
# All results from this run will be saved to sample_run/experiment0060
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 779us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 100 clusters: 0.6217758291015558
# All results from this run will be saved to sample_run/experiment0061
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 654us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 150 clusters: 0.5848340389579352
# All results from this run will be saved to sample_run/experiment0062
# #################### Beginning CFL Experiment training. ####################
# Beginning CondDensityEstimator training...
# 397/397 [==============================] - 0s 709us/step
# CondDensityEstimator training complete.
# Beginning CauseClusterer training...
# CauseClusterer training complete.
# Experiment training complete.
# abs_accuracy for 200 clusters: 0.5800131706478499

# %%
import matplotlib.pyplot as plt

plt.figure(0)
plt.plot(n_clusters, abs_accuracies)
plt.xlabel('Number of clusters')
plt.ylabel('Mean absolute error by cluster')
plt.title(f'Mean absolute error by cluster vs number of clusters - {resolution}')
# Out:
# Text(0.5, 1.0, 'Mean absolute error by cluster vs number of clusters - 10km')
